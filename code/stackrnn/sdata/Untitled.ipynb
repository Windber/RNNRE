# %%
import matplotlib.pyplot as plt

# %%
import pickle

# %%
legend = list()
d = {'srn': 'o', 'gru': '+', 'lstm': '*'}
for r in ['srn', 'gru', 'lstm']:
    fmt = d[r]
    for t in ['t1', 't2', 't3', 't4', 't5', 't6', 't7']:

        title = t + r
        if title.startswith('t2'):
            f = open(title + '_loss', 'rb')
            p = pickle.load(f)
            plt.plot(p, marker=fmt)
            legend.append(title)
plt.legend(legend, ncol=3, fontsize='small')

# %%
t = 't1'
r = 'srn'
title = t + r
f = open(title + '_loss', 'rb')
p = pickle.load(f)

# %%
plt.plot(p)
plt.legend([title])
plt.plot(p)

# %%
c(a())
# Out:
# aval
# localdval

# %%
class A:
    def a():
        pass

# %%
A.__
